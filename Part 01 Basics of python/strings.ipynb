# %%
print("Hello, Python")
# Out:
# Hello, Python

# %%
print(type("Hello, Python"))
# Out:
# <class 'str'>

# %% [markdown]
# # MUltiline string

# %%
multiline_strings = """This is a string
   that spans
   multiple lines."""
print(multiline_strings)
# Out:
# This is a string
#    that spans
#    multiple lines.

# %% [markdown]
# # Escaping Characters

# %%
#\n for new line
print("line 1\nline 2")
# Out:
# line 1
# line 2

# %%
#\t-> tab for space
print("Name:\tAlice")
# Out:
# Name:	Alice

# %%
#\\ backslash 
print("Path:C:\\Users\\Name")
# Out:
# Path:C:\Users\Name

# %%
#\'
print('It\'s raining today.')
# Out:
# It's raining today.

# %%
#\"
print("He said, \"Hello!\"")
# Out:
# He said, "Hello!"
