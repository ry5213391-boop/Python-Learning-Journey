# %%
print("Hello")
# Out:
# Hello

# %%
print('#"Hello World"')
# Out:
# #"Hello World"

# %%
print("#\"Hello World\"")
# Out:
# #"Hello World"

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a = 3.0
print(type(a))
# Out:
# <class 'float'>

# %%
s1 = "Hello World"
print(type(s1))
# Out:
# <class 'str'>

# %%
s2 = "We are learning Python"
print(type(s2))
# Out:
# <class 'str'>
