# %%
import random

# random () - returns random float between 0.0 and 1.0 (excluded)
print(random.random())
# Out:
# 0.5751481453866314

# %%
# randint(a, b)=> returns random int between a and b (both included)
print(random.randint(10, 20))
# Out:
# 14

# %%
nums = [10, 2, 4, 5, 8, 3]

#choice(sequence) => returns a random item from the sequence.
print(random.choice(nums))
# Out:
# 8

# %%
#shuffle(sequence)=> returns the elements shuffled in a random order
random.shuffle(nums)
print(nums)
# Out:
# [8, 4, 10, 3, 2, 5]
