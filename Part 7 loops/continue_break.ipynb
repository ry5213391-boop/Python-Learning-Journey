# %%
print("Roshan Yadav")
# Out:
# Roshan Yadav

# %%
for num in range(10):
    if num % 3 == 0:
        continue
    
    print(num)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8

# %%
for num in range(1, 10):
    if num % 3 == 0:
        break
    
    print(num)
# Out:
# 1
# 2
