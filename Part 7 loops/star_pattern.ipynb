# %%
print("Roshan")
# Out:
# Roshan

# %%
for i in range(1, 6):
    for j in range(1, i+1):
        print("*", end = "")
    print()

# outer loop for no. of lines
# inner loop for no. of stars
# Out:
# *
# **
# ***
# ****
# *****

# %%
""" 
*****
****
***
**
*
"""
# Out:
# ' \n*****\n'

# %%
for i in range(5, 0, -1):
    for j in range(i):
        print("*", end = "")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
# to print R using star pattern
