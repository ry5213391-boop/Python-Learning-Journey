# %%
print("H")
# Out:
# H

# %%
l1 = [5, 1.5, "Python", True, None, [1,2,3], 10]
print(len(l1))
# Out:
# 7

# %%
print(l1[-2])
# Out:
# [1, 2, 3]

# %%
print(l1[-2][0])
# Out:
# 1

# %%
l2 = [[1,2], [3,4], [5,6,[0,1]]]
print(len(l2))
# Out:
# 3

# %%
print(l2[-1][-1][-1])
# Out:
# 1
