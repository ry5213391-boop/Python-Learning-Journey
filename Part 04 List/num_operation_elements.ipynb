# %%
print("Hii")
# Out:
# Hii

# %%
numbers = [10, 4, 5.5, 7, 1]

#smallest number in the list
#print(numbers.min()) #AttributeError: 'list' object has no attribute 'min'

# %%
print(min(numbers))
#min is a universal functionused to find the minimum numbers from a list
# Out:
# 1

# %%
#max
print(max(numbers))
# Out:
# 10

# %%
#sum()
print(f"Total: {sum(numbers)}")
# Out:
# Total: 27.5
