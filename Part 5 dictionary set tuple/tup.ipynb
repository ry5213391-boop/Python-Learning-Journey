# %%
print("hii")
# Out:
# hii

# %%
#tuple = sequences of items as a collections
#(item1,item2,........)
#we cannot modify the tuple
#we cant extend the tuple
#elements are fixed
#immutable
#a tuple can be a part of tuple

# %%
t1 = ("Python", 10, 1.1, True, [1,2,3,4], (10, 20))
print(t1)
# Out:
# ('Python', 10, 1.1, True, [1, 2, 3, 4], (10, 20))

# %%
#len function
print(len(t1)) #6
# Out:
# 6

# %%
# accessing elements of a tuple
# by indexing -> pos and neg indexing
print(t1[0])
print(t1[-1])
# Out:
# Python
# (10, 20)

# %%
# Slicing
print(t1[:])
print(t1[5:])
print(t1[:5])

print(type(t1[5:]))
# Out:
# ('Python', 10, 1.1, True, [1, 2, 3, 4], (10, 20))
# ((10, 20),)
# ('Python', 10, 1.1, True, [1, 2, 3, 4])
# <class 'tuple'>

# %%
t1 = 10, 20, 30
print(t1)
print(type(t1))
#parenthesis is optional
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
l1 = [1, 2, 3]
print(type(l1))
t1 = tuple(l1)
print(t1)
print(type(t1))
# Out:
# <class 'list'>
# (1, 2, 3)
# <class 'tuple'>

# %%
fruits = ('mango', 'orange', 'apple')
print(fruits, type(fruits))
fruits = list(fruits)
print(fruits)
# Out:
# ('mango', 'orange', 'apple') <class 'tuple'>
# ['mango', 'orange', 'apple']
