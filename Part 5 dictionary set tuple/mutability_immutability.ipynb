# %%
print("Roshan")
# Out:
# Roshan

# %%
# Mutability and Immutability
#lists are mutable
# tuples and strins are immutable

# %%
s1 = "Python is fun"
print(s1.replace("Python", "Java"))
print(s1)
# strings do not change their state when they are created sp they are called immutable
# Out:
# Java is fun
# Python is fun

# %%
t1 = ("mango", "orange", "apple")
#t1.append("banana") #AttributeError

# %%
l1 = ["Mango", "Apple", "Banana"]
print(id(l1)) #id gives memory location
l1.append("Banana")
print(l1)
print(id(l1))
# memory addresses are same means that means mutable
# Out:
# 2955513602880
# ['Mango', 'Apple', 'Banana', 'Banana']
# 2955513602880

# %%
fruits = ("apple", "banana", "orange")
