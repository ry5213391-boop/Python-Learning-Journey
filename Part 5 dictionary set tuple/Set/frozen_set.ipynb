# %%
print("hii")
# Out:
# hii

# %%
s1 = {1,2,4,0}
s1.add(-1)
print(s1)
# Out:
# {0, 1, 2, 4, -1}

# %%
# frozen sets are immutable sets
fs1= frozenset({10, 20, 30})
print(fs1, type(fs1))
# Out:
# frozenset({10, 20, 30}) <class 'frozenset'>

# %%
#fs1.add(40)
#print(fs1)
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
# union, intersection, difference can be applied
fs2 = frozenset({10, 50, 100, 200})

print(fs1 & fs2)
print(fs1 | fs2)
print(fs1 - fs2)
# Out:
# frozenset({10})
# frozenset({50, 20, 100, 200, 10, 30})
# frozenset({20, 30})
