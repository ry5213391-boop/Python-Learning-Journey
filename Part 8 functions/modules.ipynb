# %%
#.py file is a module
#1. built in modulw
#2. user-defined modules

# %%
# Built-in module
#mathh, random, datetime,..

#How to import a module
#syntax -> import module_name
#Syntax for importing few functions/variable: from module_name import f1, f2, f3


import math
#calculate square root of a number
num = 100
output = math.sqrt(num)
print(output)
# Out:
# 10.0

# %%
#calculate the area of a circle
radius = 5
area_of_circle = math.pi * (radius ** 2)
print(f"Area of circle with radius {radius} is {area_of_circle}")
print(math.pi)
# Out:
# Area of circle with radius 5 is 78.53981633974483
# 3.141592653589793

# %%
from random import randint
value = randint(1, 6)
print(value)
# Out:
# 1

# %%
# syntax to create an alias for the module_name as alias_name
import datetime as dt
t = dt.time(8, 43, 51)
print(t)
# Out:
# 08:43:51

# %%
#user defined modules
import arithmetic
a = 100
b = 20
result = arithmetic.add(a, b)
print(result)

out = arithmetic.square_root(a)
print(out)
# Out:
# 120
# 10.0

# %%
import arithmetic
a = 100
out = arithmetic.square_root(a)
print(out)
# Out:
# 10.0

# %%
# for module.ipynb => __name__ => "__main__"
# for arithmetic.py => __name__ => "arithmetic"
