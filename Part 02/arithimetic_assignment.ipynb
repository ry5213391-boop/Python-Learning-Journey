# %%
x = 10
print(x)
# Out:
# 10

# %%
a = 10
a + 10
print(a)
# Out:
# 10

# %%
a = 10
a = a//5
print(a)
# Out:
# 2

# %%
a = 10
a %= 3
print(a)
# Out:
# 1

# %%
a = 10 / 3
print(a)
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
10 % 3
# Out:
# 1

# %%
3 ** 2
# Out:
# 9

# %%
value = 100#assignment operator
x = 10
x += 1
x ++ 1
x -= 3
print(x)
# Out:
# 8
