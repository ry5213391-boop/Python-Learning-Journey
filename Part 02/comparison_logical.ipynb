# %%
# coimparison operators
num1 = 10
num2 = 29
num3 = 29
print(num2 == num3)
# Out:
# True

# %%
"PYTHON" == "Python"
# Out:
# False

# %%
#!=
a = 3
b = 4
a!=b
# Out:
# True

# %%
#>, <, <=, >=

# %%
#logical and, or, not

# %%
#and
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
#not
not True
# Out:
# False

# %%
not 3
# Out:
# False

# %%
not None
# Out:
# True

# %%
not 0
# Out:
# True

# %%
not 1
# Out:
# False

# %%
name = "Mark"
age = 24
name == "Mark" and age >= 18
# Out:
# True
