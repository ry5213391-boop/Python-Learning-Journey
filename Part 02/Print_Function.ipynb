# %%
num1 = 100
print(num1)
# Out:
# 100

# %%
name = "John"
print(name)
age = 20
print(age)
print(name, age) # if we print using comma then value will be separated by using a space
print(name,age)
# Out:
# John
# 20
# John 20
# John 20

# %%
print(10, 20, 30, 40)# comma automatically gives a space
print(10,20,30,40) # separator concept
# Out:
# 10 20 30 40
# 10 20 30 40

# %%
print(10,20,30,40,sep=" ")# sep is an argument
# Out:
# 10 20 30 40

# %%
print(10,20,30,40,sep=" , ")
# Out:
# 10 , 20 , 30 , 40

# %%
print(10,20,30,40,sep="*")
# Out:
# 10*20*30*40

# %%
#print("Python') -> gives error 
print("Python")
print('python')
print('''python''')
# Out:
# Python
# python
# python

# %%
num1 = 100
num2 = 200
print(f"Addition of {num1} and {num2} is {num1 + num2}")
# Out:
# Addition of 100 and 200 is 300

# %%
name = "John"
age = 20
print("Name:", name,",",  "Age:", age)
# Out:
# Name: John , Age: 20

# %%
day = 10
month = 3
year = 2002
print(day,"/",month,"/",year)
print(day, month, year, sep="/")
# Out:
# 10 / 3 / 2002
# 10/3/2002
