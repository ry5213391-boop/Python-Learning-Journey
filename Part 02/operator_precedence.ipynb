# %%
x = 10

# %%
5 + 3 - 10 % 12 * 3 / 4 #
# Out:
# 0.5

# %% [markdown]
# # Precedence|

# %% [markdown]
# 5 + 10 * 6

# %%
5 + 10 * 6
# Out:
# 65

# %%
name = "Mark"
age = 25
print(name == "Mark" or name == "John" and age < 18)
print((name == "Mark" or name == "John") and age < 18)
# Out:
# True
# False

# %%
100/10*10
# Out:
# 100.0

# %%
2 ** 2 ** 3
# Out:
# 256

# %% [markdown]
# # Associativity
# if the operators have same precedence, then associativity from left to right or right to left will decide that which operation will happen first.

# %% [markdown]
# ## classification of operators based on number of operands

# %% [markdown]
# ### Unary operator

# %%
- 10
# Out:
# -10

# %%
not True
# Out:
# False

# %% [markdown]
# ### Binary
# - Two operands are needed

# %% [markdown]
# ### Ternary Operator
# - performed on three operands
