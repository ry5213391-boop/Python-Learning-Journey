# %%
bool('python')
# Out:
# True

# %%
bool(1000)
# Out:
# True

# %%
bool(1.5)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool(-100)
# Out:
# True

# %%
bool(10)
# Out:
# True

# %%
bool("hi")
# Out:
# True

# %%
bool(" ")
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
str(False)
# Out:
# 'False'

# %%
str(True)
# Out:
# 'True'
